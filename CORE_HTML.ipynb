# %%
#1. Build a simple webpage that displays text as shown in the below image.
<!Doctype html>
<html lang="en">
<head>
 <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
 <title>SOLUTION 1</title>
</head>
<body>
<p>  <b> THIS WILL BE BOLDED</b>                                                     </p>
<p>   <i> THIS WILL BE ITALIC</i>                                                    </p>
<p>   <mark>THIS WILL BE HIGHLITED</mark>                                            </p>
<p>   THIS IS NORMAL TEXT <sup>THIS WILL BE SUPER SCRIPTED</sup> THIS IS NORMAL AGAIN </p>
<p>   THIS IS NORMAL TEXT <sub>THIS WILL BE SUBSCRIPTED</sub>                         </p>
<p>   NORMAL TEXT <small> THIS IS SMALL TEXT </small>                                 </p>
<p>   <del> THIS WILL BE DELETED </del>                                               </p>

</body>
</html>
# Out:
#   File "<ipython-input-3-1bf44b027a8c>", line 3
#     <html>
#     ^
# SyntaxError: invalid syntax

# %%
#2. Build a simple webpage that helps users navigate different web development-related websites. Note: Onclicking the hyperlink the web pages should open in a new tab. Below is a reference image.
<!Doctype>
<html lang="en">
<head>
  <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title> SOLUTION 2 </title>
</head>
<body>
 <h2> NAVIGATE ME : </h2>
<p> CLICK TO GO ON <a href="https://pwskills.com" target="_blank"> PW SKILLS </a> </p>
  <p> CLICK TO GO ON <a href="https://www.google.com" target="_blank"> GOOGLE </a> </p>
  <p> CLICK TO GO ON <a href="https://drive.google.com" target="_blank"> DRIVE </a> </p>
</body>
</html>

# %%
#3.Build a simple blog web page with 3 pages home, web development, and web design. Each page mustcontain hyperlinks to other pages in the top, a heading of the page topic and a paragraph of information.For the home page you can add some information about yourself%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>SOLUTION 3</title>
</head>
<body>
   <!--Build a simple blog web page with 3 pages home, web development, and web design. Each page must
contain hyperlinks to other pages in the top, a heading of the page topic and a paragraph of information.
For the home page you can add some information about yourself%
-->
  <div><a href="solution3.html"> HOME </a>|
       <a href="webdevelopment.html"> WEB DEVELOPMENT </a>|
        <a href="webdesigning.html"> WEB DESIGN </a></div>
   <H1> ABOUT MYSELF </H1>
   <P> My name is Kaivalya. I am currently studying in class 11th and I am in the full stack development
     course at pw skills this is my 3rd assignment <br> and I am lucky that I took admission in pw skills
      the assignments and classes are very intresting and techers make the topics so easy that I love to
       <br> code and watch lectures for hours. I am sure that now because of pw skills I will surely get
       into any tech feild I am enjoying my journy and I am very <br> thank full to the teachers and team
        of pw skills for motivating me more and teaching me so well.    </P>
</body>
</html>

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>WEB DESIGNING (SOLUTION 3)</title>
</head>
<body>
    <div>
         <a href="solution3.html"> HOME </a>|
          <a href="webdevelopment.html"> WEB DEVELOPMENT </a>|
          <a href="webdesigning.html"> WEB DESIGN </a>
    </div>
    <h1> WEB DESIGNING </h1>
     <p>Web design is the process of planning and arranging content on a website to create a visually appealing and user-friendly experience, encompassing elements like layout, color palettes, fonts, and graphics. </p>
     <h4>KEY ELEMENTS OF WEB DESIGN </h4>
     <p>
        <ul>
           <LI> Layout: The arrangement of elements on a webpage.</LI>
           <LI>Color Palette: The selection of colors used on the website.</LI>
           <LI>Typography: The choice of fonts and their styling.</LI>
           <LI>Imagery: The use of images and other visual elements.</LI>
           <LI>Graphics: The use of graphics and other visual elements.</LI>
           <LI>Navigation: The way users move around the website.</LI>
           <LI>Usability: How easy it is for users to use the website. </LI>


        </ul>
     </p>


</body>
</html>

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>WEB DEVELOPMENT (SOLUTION 3)</title>
</head>
<body>
    <div><a href="solution3.html"> HOME </a>|
        <a href="webdevelopment.html"> WEB DEVELOPMENT </a>|
         <a href="webdesigning.html"> WEB DESIGN </a></div>
    <h1>WEB DEVELOPMENT</h1>
    <p> <ul>
          <li>Web development, also known as website development, is the process of creating and maintaining websites and web applications that run online in a web browser.</li>
         <li>It can range from simple static pages to complex web applications, e-commerce platforms, and social networking services.</li>
          <li>Web development is closely related to web design, which focuses on the visual aspects and user experience of a website, while web development focuses on the technical aspects and functionality.</li>
        </ul>
    </p>
</body>
</html>

# %%
#4Create an ordered list of HTML tags. Each list item must include the tag name and some information about the tag?
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>SOLUTION 4</title>
</head>
<body>
    <H1>HTML TAGS :</H1>
     <ol type="1">
        <LI> html: The root element of an HTML page. </LI>
        <LI> head: Contains metadata about the document, such as the title and character set.</LI>
        <LI> title: Defines the title of the document, which is displayed in the browser tab. </LI>
        <LI> body: Contains the visible content of the web page.</LI>
        <LI> h1 to h6: Defines headings of different levels.</LI>
        <LI> p: Defines a paragraph of text.</LI>
        <LI> img: Embeds an image in the page. </LI>
        <LI> a: Creates a hyperlink.</LI>
        <LI> br: Inserts a single line break.    </LI>
        <LI> ul and ol: Defines unordered and ordered lists, respectively.</LI>
        <LI> li: Defines a list item.</LI>
        <LI> table, tr, td: Defines tables, table rows, and table data cells, respectively.</LI>
     </ol>
</body>
</html>

# %%
#5. Create a description list of full stack web development tech stack, using the <dl> tag. Each term should bea tech stack name and each description should be a brief explanation of what the tech stack is used for
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title>solution 5</title>
</head>
<body>
  <h1>List of Full Stack Web Development tech stack:</h1>
    <dl>
        <dh>HTML:</dh>
        <dd>It's a markup language for creating and displaying electronic documents (web pages). They are the backbone
            in the organization and placement of content on a web page.</dd>
        <dh>CSS:</dh>
        <dd>It is responsible for the format and layout of the web pages. It includes the font styles, sizes, layout,
            color, and other aspects of a web page. Developers commonly use frameworks like SASS and LESS to make CSS
            more manageable and more dynamic.</dd>
        <dh>JavaScript:</dh>
        <dd>Used to make web pages interactive. It's a programming language that allows you to implement dynamic features on web pages; with common libraries and frameworks like jQuery, React, Angular, and Vue. Many modern applications now also use TypeScript instead of basic JavaScript. </dd>
        <dh>React.js:</dh>
        <dd>A JavaScript library for building user interfaces (UIs) that is known for its component-based approach and declarative nature.</dd>
        <dh>Node.js:</dh>
        <dd>A JavaScript runtime environment that allows developers to execute JavaScript code on the server-side, enabling real-time applications and dynamic data handling.</dd>
        <dh>Express.js:</dh>
        <dd>A minimalist web application framework for Node.js that provides a robust and lightweight foundation for building APIs and web applications.</dd>
        <dh>MongoDB:</dh>
        <dd>Stores and manages application data, providing a flexible and performant data storage solution.</dd>
    </dl>

</body>
</html>

# %%
#6.Create an ordered list of the full stack web development tech stack HTML, CSS, and JS. For each techstack, create a table that lists the tech stack name, its primary use cases, and some key features orbenefits. Below is a reference image.
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Solution 6</title>
</head>
<body>
    <h1>FULL STACK DEVELOPMENT TECH STACK:</h1>
    <ol>
        <li>
           <B>HTML:</B>
               <table border="1" cellspacing="1" cellpadding="7">
                  <tr>
                   <th>
                     PRIMARY USE CASES
                   </th>
                   <th>
                     KEY FEATURES/BENEFITS
                   </th>
                  </tr>
                  <tr>
                    <td>
                        <ul>
                          <li>building the structure of the web page</li>
                        </ul>
                    </td>
                    <td>
                        <ul>
                           <li>Simple and easy to learn</li>

                           <li>Compatible with all web browsers</li>

                           <li>allows for semantic markup</li>
                        </ul>
                    </td>
                  </tr>
                </table>
        </li>
         <br>
        <li>
          <b>CSS:</b>
            <table border="1" cellspacing="1" cellpading="7">

                <th>
                  PRIMARY USE CASE
                </th>
                 <th>
                  KEY FEATURES/BENEFITS
                 </th>
                <tr>
               <td>
                <ul>
                 <li>Styling and layout of the web page</li>
                </ul>
               </td>
               <td>
                <ul>
                  <li>
                    Allows for content separation and presentation.
                  </li>

                  <li>
                    Enables responsive design.
                  </li>

                  <li>
                    Offers a wide range of Styling options.
                  </li>
                </ul>
               </td>
              </tr>

            </table>
        </li>
        <br>
        <li>
          <b>JAVASCRIPT:</b>
          <table border="1" cellspacing="1" cellpading="7">
            <th>
              PRIMARY USE CASE
            </th>
            <th>
              KEY FEATURES/BENEFITS
            </th>
            <tr>
              <td>
                <ul>
                  <li>
                    JavaScript is for creating interactive and dynamic web pages, enhancing the user experience and functionality of websites, and it's a core language for front-end web development.
                  </li>
                </ul>
              </td>
              <td>
                <ul>
                  <li>
                    JavaScript is a dynamic, interpreted language, primarily known for its ability to make web pages interactive and dynamic
                  </li>
                  <li>
                    dynamic typing, event handling, asynchronous programming, and a rich ecosystem of libraries and frameworks.
                  </li>
                </ul>
              </td>
            </tr>


          </table>
        </li>







    </ol>
</body>
</html>

# %%
#7. Build a complex nested list structure representing a multi-level table of contents. Use unordered lists(<ul>) and list items (<li>) with inline-block styling to create a structured layout. Apply formatting tags toenhance the presentation of list items.
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <h1><b>TABLE OF CONTENTS:</b></h1>
    <ul>
        <li >
            <ins style="color: blue;">
                PART1: INTRODUCTION
            </ins>
        </li>
        <br>
        <li>
            <ins style="color: blue;">
                PART2: GETTING STARTED
            </ins>
             <ul style="circle">
                <li>
                  <ins style="color: blue;">
                     2.1 INSTALLING THE SOFTWARE
                  </ins>
                </li>
                <li>
                    <ins style="color: blue;">
                      2.2 CREATING A NEW PROJECT
                    </ins>
                </li>
                <ul type="square">
                  <li>
                    <ins style="color: blue;">
                        2.2.1 PROJECT TEMPLATES
                    </ins>
                  </li>
                  <li>
                    <ins style="color: blue;">
                      2.2.2 CUSTOMIZING SETTINGS
                    </ins>
                  </li>
                </ul>
             <li>
                <ins style="color: blue;">
                    2.3 EXPLORING THE INTERFACE
                </ins>
             </li>
                <ul style="square">
                  <li>
                    <ins style="color: blue;">
                        2.3.1 EXPLORING TOOLBAR FEATURES
                    </ins>
                  </li>
                  <li>
                    <ins style="color: blue;">
                        2.3.2 PANEL LAYOUT
                    </ins>
                  </li>
                  <ul>
                    <li>
                       <ins style="color: blue;">
                        2.3.2.1 DOCKING PANELS
                       </ins>
                    </li>
                    <li>
                        <ins style="color: blue;">
                            2.3.2.2 TABBED INTERFACE
                        </ins>
                    </li>
                  </ul>
                </ul>
            </ul>
        </li>
        <br>
        <li>
            <ins style="color: blue;">
             PART3: ADVANCED TOPICS
            </ins>
            <ul style="circle">
                <li>
                    <ins style="color:  blue;">
                     3.1 WORKING WITH PLUGINS
                    </ins>
                    <ul style="square">
                     <li>
                        <ins style="color:  blue;">
                           3.1.1 INSTALLING PLUGINS
                        </ins>
                     </li>
                     <li>
                        <ins style="color: blue;">
                           3.2.2 PLUGINS CONFIGERATION
                        </ins>
                     </li>
                    </ul>
                </li>
                <li>
                   <ins style="color: blue;">
                    3.2 COSTUMIZING THE UI
                   </ins>
                   <ul style="square">
                      <li>
                        <ins style="color: blue;">
                            3.2.1 CHANGING THEMES
                        </ins>
                      </li>
                      <li>
                        <ins style="color: blue;">
                            3.2.2 CONFIGURING SHORTCUTS
                        </ins>
                      </li>
                   </ul>
                </li>
                <li>
                    <ins style="color: blue;">
                        3.3 OPTIMISING PERFORMANCE
                    </ins>
                    <ul>
                        <li>
                            <ins style="color: blue;">
                                3.3.1 CACHING STRATERGIES
                            </ins>
                        </li>
                        <li>
                            <ins style="color: blue;">
                                3.3.2 RESOURCE MINIFICATION
                            </ins>
                        </li>
                    </ul>
                </li>

            </ul>
        </li>
        <br>
        <li>
            <ins style="color: blue;">
                PART4: CONCLUSION
            </ins>
        </li>
    </ul>
</body>
</html>

# %%
#8  Create a table to display a conference schedule. Each row corresponds to a time slot, and each columncorresponds to a room. Some time slots might have multiple sessions running simultaneously in differentrooms. Utilize rowspan and colspan attributes as necessary to accommodate this complex schedule.(use table attribute “cellpading”  to give extra padding in each table cell ).
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <h1>CONFERENCE SCHEDULE:</h1>
    <table  border= "1" cellpadding="10">
       <th>
        TIME
       </th>
       <th>
        ROOM 1
       </th>
       <TH>
        ROOM 2
       </TH>
       <TH>
        ROOM 3
       </TH>
       <TH>
        ROOM 4
       </TH>
       <tr>
        <td rowspan="3">
            9:00AM-10:00AM
        </td>
        <td rowspan="2">
            KEYNOTE
        </td>
        <TD>
            SESSION A
        </TD>
        <TD>
            SESSION B
        </TD>
        <TD rowspan="3">
            SESSION C
        </TD>
       </tr>
       <tr>
         <td>SESSION D </td>
         <td>SESSION E</td>

       </tr>
       <tr>
        <td>
            10:30AM-11:30AM
        </td>
        <td colspan="2">
            SESSION F
        </td>
       </tr>
       <tr>
        <td>
            12:00AM-1:00PM
        </td>
        <td colspan="4">
            LUNCH BREAK
        </td>
       </tr>
       <tr>
        <td rowspan="2">
            1:00PM-2:00PM
        </td>
        <td>
            SESSION G
        </td>
        <td rowspan="2">
            SESSION H
        </td>
         <td>
            SESSION I
         </td>
         <td>
            SESSION J
         </td>
       </tr>
       <tr>
        <td>
          SESSION K
        </td>
        <td>
            SESSION L
        </td>
        <td>
            SESSION M
        </td>
       </tr>
    </table>
</body>
</html>
